# %%
import pandas as pd
import os
import glob

# %%
data_dir = os.listdir()[9]

# %%
img_path_list = []
label_list = []
for case_name in os.listdir(data_dir):
    current_path = os.path.join(data_dir, case_name)
    temp = pd.read_csv(current_path, encoding='unicode_escape')
    new_df = temp.drop(0, axis=0)

# %%
current_path
# Out:
# '제10회 산업통상자원부 공공데이터활용 BI공모전_빅데이터 분석 과제 4_데이터_주요 교역국 대세계 품목별 수출입액(USD단위)\\Trade_Map_-_List_of_products_imported_by_Viet_Nam.csv'

# %%
temp
# Out:
#         Code                                      Product label  \
# 0      TOTAL                                       All products
# 1     854231  Electronic integrated circuits as processors a...
# 2     851770  Parts of telephone sets, telephones for cellul...
# 3     854232         Electronic integrated circuits as memories
# 4     854239  Electronic integrated circuits (excluding such...
# ...      ...                                                ...
# 6109  290381  1,2,3,4,5,6-Hexachlorocyclohexane (HCH (ISO)),...
# 6110  290435  Salts of perfluorooctane sulphonic acid (excl....
# 6111  290260                                       Ethylbenzene
# 6112  290241                                           O-Xylene
# 6113  284450  Spent ""irradiated"" fuel elements ""cartridge...
#
#       Imported value in 2012  Imported value in 2013  Imported value in 2014  \
# 0                  113780431               132032531               147839048
# ...

# %%
new_df["HS"]=new_df["Code"].str[0:1].astype('int')

# %%
new_df.groupby('HS').sum()
# Out:
#     Imported value in 2012  Imported value in 2013  Imported value in 2014  \
# HS
# 1                  4118259                 4241415                 5128722
# 2                 18344172                18152907                19139768
# 3                 15069863                17109391                18847447
# 4                  6405718                 7129801                 8678296
# 5                  8516724                 9876340                11135263
# 6                  3417429                 4273510                 4956933
# 7                 14151316                15707471                17996668
# 8                 40205016                51145171                56841315
# 9                  3551911                 4396559                 5114659
#
#     Imported value in 2015  Imported value in 2016  Imported value in 2017  \
# HS
# 1                  5566990                 6011771                 5870573
# ...

# %%
new_temp = new_df.groupby('HS').sum()

# %%
import matplotlib.pyplot as plt

ratio = new_temp['Imported value in 2012']
labels = new_temp.index

plt.pie(ratio, labels=labels, autopct='%.1f%%')
plt.show()
